# %% [markdown]
# ---
#
# # Atenção!
#
# Lembre-se de clonar este notebook antes de tentar editar as células de código.
#
# Para isso, basta seguir os passos:
#
# File -> Save a copy in Drive
#
#
#
# ---

# %%
# !git clone https://github.com/loggi/loggibud
# %cd /content/loggibud/

# Instale as dependências do projeto
# !pip install poetry
# !poetry install
# Se você estiver executando esse script localmente, não precisa dos dois comandos abaixo
# !poetry export -f requirements.txt --without-hashes --output requirements.txt
# !pip install -r requirements.txt

# Verifique se tudo funcionou executando os testes
# !poetry run pytest -s -v tests/

# Baixe os dados compilados
# !wget -nc https://loggibud.s3.amazonaws.com/dataset.zip
# !unzip -n dataset.zip

# Verifique que a pasta `data/` agora não está mais vazia
# !ls data/
# Out:
# Cloning into 'loggibud'...
# remote: Enumerating objects: 967, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 967 (delta 45), reused 58 (delta 33), pack-reused 871
# Receiving objects: 100% (967/967), 6.42 MiB | 12.28 MiB/s, done.
# Resolving deltas: 100% (502/502), done.
# /content/loggibud
# Collecting poetry
#   Downloading poetry-1.1.11-py2.py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 7.1 MB/s
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from poetry) (4.8.0)
# Collecting tomlkit<1.0.0,>=0.7.0
#   Downloading tomlkit-0.7.2-py2.py3-none-any.whl (32 kB)
# Collecting crashtest<0.4.0,>=0.3.0
#   Downloading crashtest-0.3.1-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: cachecontrol[filecache]<0.13.0,>=0.12.4 in /usr/local/lib/python3.7/dist-packages (from poetry) (0.12.6)
# Collecting packaging<21.0,>=20.4
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 7.2 MB/s
# Collecting cachy<0.4.0,>=0.3.0
#   Downloading cachy-0.3.0-py2.py3-none-any.whl (20 kB)
# Collecting pkginfo<2.0,>=1.4
#   Downloading pkginfo-1.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: html5lib<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from poetry) (1.0.1)
# Collecting keyring<22.0.0,>=21.2.0
#   Downloading keyring-21.8.0-py3-none-any.whl (32 kB)
# Collecting poetry-core<1.1.0,>=1.0.7
#   Downloading poetry_core-1.0.7-py2.py3-none-any.whl (424 kB)
#      |████████████████████████████████| 424 kB 51.3 MB/s
# Requirement already satisfied: requests<3.0,>=2.18 in /usr/local/lib/python3.7/dist-packages (from poetry) (2.23.0)
# Collecting importlib-metadata<2.0.0,>=1.6.0
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting requests-toolbelt<0.10.0,>=0.9.1
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.6 MB/s
# Collecting virtualenv<21.0.0,>=20.0.26
#   Downloading virtualenv-20.8.1-py2.py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 38.8 MB/s
# Collecting shellingham<2.0,>=1.1
#   Downloading shellingham-1.4.0-py2.py3-none-any.whl (9.4 kB)
# Collecting cleo<0.9.0,>=0.8.1
#   Downloading cleo-0.8.1-py2.py3-none-any.whl (21 kB)
# Collecting clikit<0.7.0,>=0.6.2
#   Downloading clikit-0.6.2-py2.py3-none-any.whl (91 kB)
#      |████████████████████████████████| 91 kB 11.7 MB/s
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from cachecontrol[filecache]<0.13.0,>=0.12.4->poetry) (1.0.2)
# Collecting lockfile>=0.9
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Collecting pylev<2.0,>=1.3
#   Downloading pylev-1.4.0-py2.py3-none-any.whl (6.1 kB)
# Collecting pastel<0.3.0,>=0.2.0
#   Downloading pastel-0.2.1-py2.py3-none-any.whl (6.0 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from html5lib<2.0,>=1.0->poetry) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib<2.0,>=1.0->poetry) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<2.0.0,>=1.6.0->poetry) (3.6.0)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.2 MB/s
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging<21.0,>=20.4->poetry) (2.4.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect<5.0.0,>=4.7.0->poetry) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->poetry) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->poetry) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->poetry) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->poetry) (2.10)
# Collecting cryptography>=2.0
#   Downloading cryptography-35.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 46.8 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring<22.0.0,>=21.2.0->poetry) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring<22.0.0,>=21.2.0->poetry) (2.20)
# Collecting backports.entry-points-selectable>=1.0.4
#   Downloading backports.entry_points_selectable-1.1.0-py2.py3-none-any.whl (6.2 kB)
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.4.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: filelock<4,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from virtualenv<21.0.0,>=20.0.26->poetry) (3.3.0)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.3-py2.py3-none-any.whl (496 kB)
#      |████████████████████████████████| 496 kB 54.1 MB/s
# Installing collected packages: pylev, pastel, jeepney, importlib-metadata, cryptography, crashtest, SecretStorage, platformdirs, lockfile, distlib, clikit, backports.entry-points-selectable, virtualenv, tomlkit, shellingham, requests-toolbelt, poetry-core, pkginfo, packaging, keyring, cleo, cachy, poetry
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.8.1
#     Uninstalling importlib-metadata-4.8.1:
#       Successfully uninstalled importlib-metadata-4.8.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed SecretStorage-3.3.1 backports.entry-points-selectable-1.1.0 cachy-0.3.0 cleo-0.8.1 clikit-0.6.2 crashtest-0.3.1 cryptography-35.0.0 distlib-0.3.3 importlib-metadata-1.7.0 jeepney-0.7.1 keyring-21.8.0 lockfile-0.12.2 packaging-20.9 pastel-0.2.1 pkginfo-1.7.1 platformdirs-2.4.0 poetry-1.1.11 poetry-core-1.0.7 pylev-1.4.0 requests-toolbelt-0.9.1 shellingham-1.4.0 tomlkit-0.7.2 virtualenv-20.8.1
# Creating virtualenv loggibud-3SbdMl6d-py3.7 in /root/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
#
# Package operations: 76 installs, 0 updates, 0 removals
#
#   • Installing ipython-genutils (0.2.0): Pending...
#   • Installing ipython-genutils (0.2.0): Downloading... 0%
#   • Installing ipython-genutils (0.2.0): Downloading... 100%
#   • Installing ipython-genutils (0.2.0): Downloading... 100%
#   • Installing ipython-genutils (0.2.0): Installing...
#   • Installing ipython-genutils (0.2.0)
#   • Installing click (7.1.2): Pending...
#   • Installing decorator (5.0.9): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing decorator (5.0.9): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing click (7.1.2): Downloading... 0%
#   • Installing decorator (5.0.9): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing decorator (5.0.9): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing click (7.1.2): Downloading... 100%
#   • Installing decorator (5.0.9): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing decorator (5.0.9): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing click (7.1.2): Downloading... 100%
#   • Installing decorator (5.0.9): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing decorator (5.0.9): Downloading... 0%
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing decorator (5.0.9): Downloading... 100%
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing decorator (5.0.9): Downloading... 100%
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing click (7.1.2): Installing...
#   • Installing decorator (5.0.9): Downloading... 100%
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing decorator (5.0.9): Downloading... 100%
#   • Installing markupsafe (2.0.1): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing markupsafe (2.0.1): Downloading... 0%
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing parso (0.8.2): Downloading... 0%
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing ptyprocess (0.7.0): Downloading... 0%
#   • Installing markupsafe (2.0.1): Downloading... 0%
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Downloading... 0%
#   • Installing ptyprocess (0.7.0): Downloading... 0%
#   • Installing decorator (5.0.9): Installing...
#   • Installing markupsafe (2.0.1): Downloading... 0%
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Downloading... 0%
#   • Installing ptyprocess (0.7.0): Downloading... 0%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Downloading... 0%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing markupsafe (2.0.1): Downloading... 100%
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Downloading... 0%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing parso (0.8.2): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing parso (0.8.2): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing markupsafe (2.0.1): Downloading... 100%
#   • Installing numpy (1.20.3): Pending...
#   • Installing parso (0.8.2): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 0%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 0%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing markupsafe (2.0.1): Installing...
#   • Installing numpy (1.20.3): Downloading... 0%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 10%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 30%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 50%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 70%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 90%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 100%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Downloading... 100%
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing numpy (1.20.3): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing markupsafe (2.0.1): Installing...
#   • Installing numpy (1.20.3): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing decorator (5.0.9)
#   • Installing markupsafe (2.0.1): Installing...
#   • Installing numpy (1.20.3): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0): Installing...
#   • Installing six (1.16.0): Pending...
#   • Installing six (1.16.0): Pending...
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0): Pending...
#   • Installing traitlets (5.0.5): Pending...
#   • Installing traitlets (5.0.5): Pending...
#   • Installing six (1.16.0): Downloading... 0%
#   • Installing traitlets (5.0.5): Pending...
#   • Installing traitlets (5.0.5): Pending...
#   • Installing six (1.16.0): Downloading... 100%
#   • Installing traitlets (5.0.5): Pending...
#   • Installing traitlets (5.0.5): Pending...
#   • Installing six (1.16.0): Downloading... 100%
#   • Installing traitlets (5.0.5): Pending...
#   • Installing numpy (1.20.3): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0): Downloading... 100%
#   • Installing traitlets (5.0.5): Pending...
#   • Installing markupsafe (2.0.1)
#   • Installing numpy (1.20.3): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0): Downloading... 100%
#   • Installing traitlets (5.0.5): Pending...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing traitlets (5.0.5): Pending...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing six (1.16.0): Installing...
#   • Installing traitlets (5.0.5): Pending...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing traitlets (5.0.5): Downloading... 0%
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing traitlets (5.0.5): Downloading... 100%
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing traitlets (5.0.5): Downloading... 100%
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing traitlets (5.0.5): Installing...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing decorator (5.0.9)
#   • Installing markupsafe (2.0.1)
#   • Installing numpy (1.20.3): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0): Installing...
#   • Installing traitlets (5.0.5): Installing...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing click (7.1.2)
#   • Installing decorator (5.0.9)
#   • Installing markupsafe (2.0.1)
#   • Installing numpy (1.20.3): Installing...
#   • Installing parso (0.8.2): Installing...
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0): Installing...
#   • Installing traitlets (5.0.5): Installing...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0): Installing...
#   • Installing traitlets (5.0.5): Installing...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing parso (0.8.2)
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0): Installing...
#   • Installing traitlets (5.0.5): Installing...
#   • Installing typing-extensions (3.10.0.0): Pending...
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing typing-extensions (3.10.0.0): Downloading... 0%
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing typing-extensions (3.10.0.0): Downloading... 100%
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing typing-extensions (3.10.0.0): Downloading... 100%
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing typing-extensions (3.10.0.0): Installing...
#   • Installing wcwidth (0.2.5): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing wrapt (1.12.1): Pending...
#   • Installing wcwidth (0.2.5): Downloading... 0%
#   • Installing wrapt (1.12.1): Pending...
#   • Installing wrapt (1.12.1): Downloading... 0%
#   • Installing wrapt (1.12.1): Downloading... 100%
#   • Installing wrapt (1.12.1): Downloading... 100%
#   • Installing wcwidth (0.2.5): Downloading... 100%
#   • Installing wrapt (1.12.1): Downloading... 100%
#   • Installing wrapt (1.12.1): Downloading... 100%
#   • Installing wcwidth (0.2.5): Downloading... 100%
#   • Installing wrapt (1.12.1): Downloading... 100%
#   • Installing wrapt (1.12.1): Downloading... 100%
#   • Installing wrapt (1.12.1): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing wcwidth (0.2.5): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing traitlets (5.0.5): Installing...
#   • Installing typing-extensions (3.10.0.0): Installing...
#   • Installing wcwidth (0.2.5): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing six (1.16.0)
#   • Installing traitlets (5.0.5): Installing...
#   • Installing typing-extensions (3.10.0.0): Installing...
#   • Installing wcwidth (0.2.5): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1): Pending...
#   • Installing zipp (3.4.1): Downloading... 0%
#   • Installing zipp (3.4.1): Downloading... 100%
#   • Installing zipp (3.4.1): Downloading... 100%
#   • Installing zipp (3.4.1): Installing...
#   • Installing wcwidth (0.2.5): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1): Installing...
#   • Installing typing-extensions (3.10.0.0)
#   • Installing wcwidth (0.2.5): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1): Installing...
#   • Installing typing-extensions (3.10.0.0)
#   • Installing wcwidth (0.2.5): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1): Installing...
#   • Installing traitlets (5.0.5)
#   • Installing typing-extensions (3.10.0.0)
#   • Installing wcwidth (0.2.5): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1): Installing...
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1): Installing...
#   • Installing wcwidth (0.2.5)
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1): Installing...
#   • Installing zipp (3.4.1)
#   • Installing parso (0.8.2)
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0)
#   • Installing traitlets (5.0.5)
#   • Installing typing-extensions (3.10.0.0)
#   • Installing wcwidth (0.2.5)
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1)
#   • Installing numpy (1.20.3)
#   • Installing parso (0.8.2)
#   • Installing ptyprocess (0.7.0)
#   • Installing six (1.16.0)
#   • Installing traitlets (5.0.5)
#   • Installing typing-extensions (3.10.0.0)
#   • Installing wcwidth (0.2.5)
#   • Installing wrapt (1.12.1): Installing...
#   • Installing zipp (3.4.1)
#   • Installing zipp (3.4.1)
#   • Installing wrapt (1.12.1)
#   • Installing zipp (3.4.1)
#   • Installing attrs (21.2.0): Pending...
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing attrs (21.2.0): Downloading... 0%
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing attrs (21.2.0): Downloading... 100%
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing attrs (21.2.0): Downloading... 100%
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing attrs (21.2.0): Installing...
#   • Installing backcall (0.2.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing backcall (0.2.0): Downloading... 0%
#   • Installing certifi (2021.5.30): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing click-plugins (1.1.1): Downloading... 0%
#   • Installing cligj (0.6.0): Pending...
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Downloading... 0%
#   • Installing cligj (0.6.0): Pending...
#   • Installing certifi (2021.5.30): Downloading... 0%
#   • Installing chardet (4.0.0): Pending...
#   • Installing click-plugins (1.1.1): Downloading... 0%
#   • Installing cligj (0.6.0): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing click-plugins (1.1.1): Downloading... 100%
#   • Installing cligj (0.6.0): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing click-plugins (1.1.1): Downloading... 100%
#   • Installing cligj (0.6.0): Pending...
#   • Installing cligj (0.6.0): Pending...
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing certifi (2021.5.30): Downloading... 0%
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing backcall (0.2.0): Downloading... 100%
#   • Installing certifi (2021.5.30): Downloading... 0%
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing certifi (2021.5.30): Downloading... 100%
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing certifi (2021.5.30): Downloading... 100%
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing certifi (2021.5.30): Downloading... 100%
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing backcall (0.2.0): Downloading... 100%
#   • Installing certifi (2021.5.30): Downloading... 100%
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing certifi (2021.5.30): Installing...
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing certifi (2021.5.30): Installing...
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing backcall (0.2.0): Installing...
#   • Installing certifi (2021.5.30): Installing...
#   • Installing chardet (4.0.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Pending...
#   • Installing cligj (0.6.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Downloading... 0%
#   • Installing chardet (4.0.0): Downloading... 100%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Downloading... 0%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Downloading... 0%
#   • Installing chardet (4.0.0): Downloading... 100%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Downloading... 0%
#   • Installing cligj (0.6.0): Downloading... 100%
#   • Installing cligj (0.6.0): Downloading... 100%
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Downloading... 100%
#   • Installing chardet (4.0.0): Installing...
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Downloading... 100%
#   • Installing cligj (0.6.0): Installing...
#   • Installing certifi (2021.5.30): Installing...
#   • Installing chardet (4.0.0): Installing...
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Installing...
#   • Installing backcall (0.2.0)
#   • Installing certifi (2021.5.30): Installing...
#   • Installing chardet (4.0.0): Installing...
#   • Installing click-plugins (1.1.1): Installing...
#   • Installing cligj (0.6.0): Installing...
#   • Installing deprecated (1.2.12): Pending...
#   • Installing cligj (0.6.0): Installing...
#   • Installing deprecated (1.2.12): Pending...
#   • Installing click-plugins (1.1.1)
#   • Installing cligj (0.6.0): Installing...
#   • Installing deprecated (1.2.12): Pending...
#   • Installing idna (2.10): Pending...
#   • Installing idna (2.10): Pending...
#   • Installing deprecated (1.2.12): Downloading... 0%
#   • Installing idna (2.10): Pending...
#   • Installing idna (2.10): Pending...
#   • Installing deprecated (1.2.12): Downloading... 100%
#   • Installing idna (2.10): Pending...
#   • Installing idna (2.10): Pending...
#   • Installing deprecated (1.2.12): Downloading... 100%
#   • Installing idna (2.10): Pending...
#   • Installing backcall (0.2.0)
#   • Installing certifi (2021.5.30): Installing...
#   • Installing chardet (4.0.0): Installing...
#   • Installing click-plugins (1.1.1)
#   • Installing cligj (0.6.0): Installing...
#   • Installing deprecated (1.2.12): Downloading... 100%
#   • Installing idna (2.10): Pending...
#   • Installing attrs (21.2.0)
#   • Installing backcall (0.2.0)
#   • Installing certifi (2021.5.30): Installing...
#   • Installing chardet (4.0.0): Installing...
#   • Installing click-plugins (1.1.1)
#   • Installing cligj (0.6.0): Installing...
#   • Installing deprecated (1.2.12): Downloading... 100%
#   • Installing idna (2.10): Pending...
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing idna (2.10): Pending...
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing deprecated (1.2.12): Installing...
#   • Installing idna (2.10): Pending...
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing idna (2.10): Downloading... 0%
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing chardet (4.0.0): Installing...
#   • Installing click-plugins (1.1.1)
#   • Installing cligj (0.6.0): Installing...
#   • Installing deprecated (1.2.12): Installing...
#   • Installing idna (2.10): Downloading... 0%
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing certifi (2021.5.30)
#   • Installing chardet (4.0.0): Installing...
#   • Installing click-plugins (1.1.1)
#   • Installing cligj (0.6.0): Installing...
#   • Installing deprecated (1.2.12): Installing...
#   • Installing idna (2.10): Downloading... 0%
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing deprecated (1.2.12): Installing...
#   • Installing idna (2.10): Downloading... 0%
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing cligj (0.6.0)
#   • Installing deprecated (1.2.12): Installing...
#   • Installing idna (2.10): Downloading... 0%
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing idna (2.10): Downloading... 100%
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing idna (2.10): Downloading... 100%
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing idna (2.10): Installing...
#   • Installing importlib-metadata (4.5.0): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing importlib-metadata (4.5.0): Downloading... 0%
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing importlib-metadata (4.5.0): Downloading... 100%
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing importlib-metadata (4.5.0): Downloading... 100%
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing importlib-metadata (4.5.0): Installing...
#   • Installing jedi (0.18.0): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing jedi (0.18.0): Downloading... 0%
#   • Installing jinja2 (3.0.1): Pending...
#   • Installing jinja2 (3.0.1): Downloading... 0%
#   • Installing jinja2 (3.0.1): Downloading... 100%
#   • Installing jinja2 (3.0.1): Downloading... 100%
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing jedi (0.18.0): Downloading... 100%
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing jedi (0.18.0): Downloading... 100%
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing click-plugins (1.1.1)
#   • Installing cligj (0.6.0)
#   • Installing deprecated (1.2.12): Installing...
#   • Installing idna (2.10): Installing...
#   • Installing importlib-metadata (4.5.0): Installing...
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing chardet (4.0.0)
#   • Installing click-plugins (1.1.1)
#   • Installing cligj (0.6.0)
#   • Installing deprecated (1.2.12): Installing...
#   • Installing idna (2.10): Installing...
#   • Installing importlib-metadata (4.5.0): Installing...
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing joblib (1.0.1): Pending...
#   • Installing joblib (1.0.1): Downloading... 0%
#   • Installing joblib (1.0.1): Downloading... 100%
#   • Installing joblib (1.0.1): Downloading... 100%
#   • Installing joblib (1.0.1): Installing...
#   • Installing idna (2.10): Installing...
#   • Installing importlib-metadata (4.5.0): Installing...
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing joblib (1.0.1): Installing...
#   • Installing deprecated (1.2.12)
#   • Installing idna (2.10): Installing...
#   • Installing importlib-metadata (4.5.0): Installing...
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing joblib (1.0.1): Installing...
#   • Installing matplotlib-inline (0.1.2): Pending...
#   • Installing matplotlib-inline (0.1.2): Downloading... 0%
#   • Installing matplotlib-inline (0.1.2): Downloading... 100%
#   • Installing matplotlib-inline (0.1.2): Downloading... 100%
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing joblib (1.0.1): Installing...
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing importlib-metadata (4.5.0)
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing joblib (1.0.1): Installing...
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing munch (2.5.0): Pending...
#   • Installing munch (2.5.0): Downloading... 0%
#   • Installing importlib-metadata (4.5.0)
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing joblib (1.0.1): Installing...
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing munch (2.5.0): Downloading... 0%
#   • Installing idna (2.10)
#   • Installing importlib-metadata (4.5.0)
#   • Installing jedi (0.18.0): Installing...
#   • Installing jinja2 (3.0.1): Installing...
#   • Installing joblib (1.0.1): Installing...
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing munch (2.5.0): Downloading... 0%
#   • Installing networkx (2.5): Pending...
#   • Installing networkx (2.5): Pending...
#   • Installing munch (2.5.0): Downloading... 100%
#   • Installing networkx (2.5): Pending...
#   • Installing networkx (2.5): Pending...
#   • Installing munch (2.5.0): Downloading... 100%
#   • Installing networkx (2.5): Pending...
#   • Installing networkx (2.5): Pending...
#   • Installing munch (2.5.0): Installing...
#   • Installing networkx (2.5): Pending...
#   • Installing joblib (1.0.1): Installing...
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing munch (2.5.0): Installing...
#   • Installing networkx (2.5): Pending...
#   • Installing jinja2 (3.0.1)
#   • Installing joblib (1.0.1): Installing...
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing munch (2.5.0): Installing...
#   • Installing networkx (2.5): Pending...
#   • Installing pexpect (4.8.0): Pending...
#   • Installing pexpect (4.8.0): Pending...
#   • Installing networkx (2.5): Downloading... 0%
#   • Installing pexpect (4.8.0): Pending...
#   • Installing pexpect (4.8.0): Pending...
#   • Installing networkx (2.5): Downloading... 70%
#   • Installing pexpect (4.8.0): Pending...
#   • Installing pexpect (4.8.0): Pending...
#   • Installing networkx (2.5): Downloading... 100%
#   • Installing pexpect (4.8.0): Pending...
#   • Installing pexpect (4.8.0): Pending...
#   • Installing networkx (2.5): Downloading... 100%
#   • Installing pexpect (4.8.0): Pending...
#   • Installing pexpect (4.8.0): Downloading... 0%
#   • Installing pexpect (4.8.0): Downloading... 100%
#   • Installing pexpect (4.8.0): Downloading... 100%
#   • Installing pexpect (4.8.0): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing munch (2.5.0): Installing...
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing joblib (1.0.1)
#   • Installing matplotlib-inline (0.1.2): Installing...
#   • Installing munch (2.5.0): Installing...
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing pickleshare (0.7.5): Pending...
#   • Installing pickleshare (0.7.5): Downloading... 0%
#   • Installing pickleshare (0.7.5): Downloading... 100%
#   • Installing pickleshare (0.7.5): Downloading... 100%
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing munch (2.5.0): Installing...
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing matplotlib-inline (0.1.2)
#   • Installing munch (2.5.0): Installing...
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing prompt-toolkit (3.0.18): Pending...
#   • Installing prompt-toolkit (3.0.18): Downloading... 0%
#   • Installing prompt-toolkit (3.0.18): Downloading... 100%
#   • Installing prompt-toolkit (3.0.18): Downloading... 100%
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing munch (2.5.0)
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing pygments (2.9.0): Pending...
#   • Installing pygments (2.9.0): Downloading... 0%
#   • Installing pygments (2.9.0): Downloading... 100%
#   • Installing pygments (2.9.0): Downloading... 100%
#   • Installing pygments (2.9.0): Installing...
#   • Installing jinja2 (3.0.1)
#   • Installing joblib (1.0.1)
#   • Installing matplotlib-inline (0.1.2)
#   • Installing munch (2.5.0)
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing pygments (2.9.0): Installing...
#   • Installing jedi (0.18.0)
#   • Installing jinja2 (3.0.1)
#   • Installing joblib (1.0.1)
#   • Installing matplotlib-inline (0.1.2)
#   • Installing munch (2.5.0)
#   • Installing networkx (2.5): Installing...
#   • Installing pexpect (4.8.0): Installing...
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing pygments (2.9.0): Installing...
#   • Installing pyparsing (2.4.7): Pending...
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing pygments (2.9.0): Installing...
#   • Installing pyparsing (2.4.7): Pending...
#   • Installing pexpect (4.8.0)
#   • Installing pickleshare (0.7.5): Installing...
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing pygments (2.9.0): Installing...
#   • Installing pyparsing (2.4.7): Pending...
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing pyparsing (2.4.7): Downloading... 0%
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing pyparsing (2.4.7): Downloading... 100%
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing pyparsing (2.4.7): Downloading... 100%
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing pyparsing (2.4.7): Installing...
#   • Installing python-dateutil (2.8.1): Pending...
#   • Installing python-dateutil (2.8.1): Downloading... 0%
#   • Installing python-dateutil (2.8.1): Downloading... 100%
#   • Installing python-dateutil (2.8.1): Downloading... 100%
#   • Installing python-dateutil (2.8.1): Installing...
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing pygments (2.9.0): Installing...
#   • Installing pyparsing (2.4.7): Installing...
#   • Installing python-dateutil (2.8.1): Installing...
#   • Installing pickleshare (0.7.5)
#   • Installing prompt-toolkit (3.0.18): Installing...
#   • Installing pygments (2.9.0): Installing...
#   • Installing pyparsing (2.4.7): Installing...
#   • Installing python-dateutil (2.8.1): Installing...
#   • Installing pytz (2021.1): Pending...
#   • Installing pytz (2021.1): Downloading... 0%
#   • Installing pytz (2021.1): Downloading... 100%
#   • Installing pytz (2021.1): Downloading... 100%
#   • Installing pytz (2021.1): Installing...
#   • Installing python-dateutil (2.8.1): Installing...
#   • Installing pytz (2021.1): Installing...
#   • Installing pyparsing (2.4.7)
#   • Installing python-dateutil (2.8.1): Installing...
#   • Installing pytz (2021.1): Installing...
#   • Installing scipy (1.6.1): Pending...
#   • Installing pytz (2021.1): Installing...
#   • Installing scipy (1.6.1): Pending...
#   • Installing python-dateutil (2.8.1)
#   • Installing pytz (2021.1): Installing...
#   • Installing scipy (1.6.1): Pending...
#   • Installing tabulate (0.8.9): Pending...
#   • Installing pygments (2.9.0): Installing...
#   • Installing pyparsing (2.4.7)
#   • Installing python-dateutil (2.8.1)
#   • Installing pytz (2021.1): Installing...
#   • Installing scipy (1.6.1): Pending...
#   • Installing tabulate (0.8.9): Pending...
#   • Installing prompt-toolkit (3.0.18)
#   • Installing pygments (2.9.0): Installing...
#   • Installing pyparsing (2.4.7)
#   • Installing python-dateutil (2.8.1)
#   • Installing pytz (2021.1): Installing...
#   • Installing scipy (1.6.1): Pending...
#   • Installing tabulate (0.8.9): Pending...
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing tabulate (0.8.9): Downloading... 0%
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing tabulate (0.8.9): Downloading... 100%
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing tabulate (0.8.9): Downloading... 100%
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing tabulate (0.8.9): Installing...
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing tabulate (0.8.9): Installing...
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing scipy (1.6.1): Downloading... 0%
#   • Installing tabulate (0.8.9): Installing...
#   • Installing threadpoolctl (2.1.0): Pending...
#   • Installing threadpoolctl (2.1.0): Downloading... 0%
#   • Installing threadpoolctl (2.1.0): Downloading... 100%
#   • Installing threadpoolctl (2.1.0): Downloading... 100%
#   • Installing threadpoolctl (2.1.0): Installing...
#   • Installing tabulate (0.8.9): Installing...
#   • Installing threadpoolctl (2.1.0): Installing...
#   • Installing scipy (1.6.1): Downloading... 10%
#   • Installing tabulate (0.8.9): Installing...
#   • Installing threadpoolctl (2.1.0): Installing...
#   • Installing tabulate (0.8.9): Installing...
#   • Installing threadpoolctl (2.1.0): Installing...
#   • Installing scipy (1.6.1): Downloading... 20%
#   • Installing tabulate (0.8.9): Installing...
#   • Installing threadpoolctl (2.1.0): Installing...
# ...
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-93.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-102.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-90.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-98.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-105.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-108.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-100.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-110.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-115.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-113.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-119.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-96.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-99.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-112.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-97.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-111.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-91.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-95.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-107.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-116.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-109.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-104.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-101.json
#   inflating: data/cvrp-instances-1.0/dev/rj-1/cvrp-1-rj-94.json
#    creating: data/cvrp-instances-1.0/dev/rj-3/
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-92.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-95.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-109.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-107.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-111.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-100.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-99.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-114.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-94.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-96.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-105.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-112.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-102.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-97.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-110.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-103.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-93.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-118.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-113.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-108.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-117.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-98.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-116.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-90.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-91.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-119.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-115.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-104.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-101.json
#   inflating: data/cvrp-instances-1.0/dev/rj-3/cvrp-3-rj-106.json
#    creating: data/cvrp-instances-1.0/dev/pa-0/
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-93.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-102.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-113.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-96.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-118.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-104.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-107.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-95.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-100.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-101.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-109.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-103.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-119.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-108.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-92.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-106.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-114.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-90.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-91.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-111.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-116.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-99.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-117.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-115.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-105.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-97.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-110.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-112.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-98.json
#   inflating: data/cvrp-instances-1.0/dev/pa-0/cvrp-0-pa-94.json
#    creating: data/cvrp-instances-1.0/dev/df-2/
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-110.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-102.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-104.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-107.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-118.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-106.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-103.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-119.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-108.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-116.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-100.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-111.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-113.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-97.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-99.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-95.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-94.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-90.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-109.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-105.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-117.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-91.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-93.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-92.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-112.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-96.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-115.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-101.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-114.json
#   inflating: data/cvrp-instances-1.0/dev/df-2/cvrp-2-df-98.json
#    creating: data/cvrp-instances-1.0/dev/rj-4/
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-102.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-109.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-101.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-91.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-114.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-104.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-112.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-108.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-107.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-90.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-113.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-115.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-96.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-119.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-94.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-118.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-103.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-116.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-95.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-99.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-105.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-110.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-92.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-111.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-106.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-117.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-97.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-98.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-93.json
#   inflating: data/cvrp-instances-1.0/dev/rj-4/cvrp-4-rj-100.json
#    creating: data/cvrp-instances-1.0/dev/df-1/
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-92.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-106.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-110.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-109.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-90.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-103.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-118.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-93.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-94.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-113.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-105.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-119.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-107.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-117.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-114.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-116.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-111.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-101.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-112.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-98.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-104.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-91.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-97.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-99.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-95.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-100.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-115.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-108.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-102.json
#   inflating: data/cvrp-instances-1.0/dev/df-1/cvrp-1-df-96.json
#    creating: data/cvrp-instances-1.0/dev/rj-2/
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-112.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-100.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-111.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-110.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-107.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-95.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-106.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-93.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-108.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-109.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-91.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-105.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-104.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-113.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-102.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-90.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-97.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-118.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-94.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-103.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-114.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-117.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-98.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-92.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-116.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-119.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-96.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-115.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-99.json
#   inflating: data/cvrp-instances-1.0/dev/rj-2/cvrp-2-rj-101.json
#    creating: data/cvrp-instances-1.0/dev/pa-1/
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-119.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-115.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-90.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-98.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-104.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-101.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-106.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-99.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-92.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-117.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-103.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-97.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-111.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-93.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-116.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-110.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-96.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-100.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-108.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-112.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-114.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-91.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-94.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-113.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-109.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-107.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-105.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-102.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-118.json
#   inflating: data/cvrp-instances-1.0/dev/pa-1/cvrp-1-pa-95.json
# cvrp-instances-1.0  delivery-instances-1.0

# %%
# Arquivo de configuração para acessar o OSRM
from loggibud.v1.distances import OSRMConfig


osrm_config = OSRMConfig(host="http://ec2-34-222-175-250.us-west-2.compute.amazonaws.com")
osrm_config
# Out:
# OSRMConfig(host='http://ec2-34-222-175-250.us-west-2.compute.amazonaws.com', timeout_s=600)

# %% [markdown]
# # Exercício 1

# %% [markdown]
# Comecemos importando a instância desejada:

# %%
from loggibud.v1.types import CVRPInstance

file_path = "./data/cvrp-instances-1.0/train/df-0/cvrp-0-df-0.json"
problem = CVRPInstance.from_file(file_path)
problem
# Out:
# CVRPInstance(name='cvrp-0-df-0', region='df-0', origin=Point(lng=-47.802664728268745, lat=-15.657013854445248), vehicle_capacity=180, deliveries=[Delivery(id='ed0993f8cc70d998342f38ee827176dc', point=Point(lng=-47.7496622016347, lat=-15.65879313293694), size=10), Delivery(id='c7220154adc7a3def8f0b2b8a42677a9', point=Point(lng=-47.75887552060412, lat=-15.651440380492554), size=10), Delivery(id='54e598b20ffa2707d01b1ac00942793f', point=Point(lng=-47.755018806591394, lat=-15.651207309372888), size=7), Delivery(id='64812681ba8c280649f764b9fb40936a', point=Point(lng=-47.758785390289965, lat=-15.648706444367969), size=3), Delivery(id='c17ea5bb3bdb1346ea358516cba81e5c', point=Point(lng=-47.75284167302011, lat=-15.66047286919706), size=10), Delivery(id='fb1b2bc2ac3783706de766e715cb9d01', point=Point(lng=-47.74788198106806, lat=-15.663388754816273), size=3), Delivery(id='c667f779151bd4e23e91d3b4659ffd94', point=Point(lng=-47.75836162961292, lat=-15.648355505737312), size=5), Delivery(id='7b315f77e3dfded7448866984942da14', point=Point(lng=-47.71947511765923, lat=-15.696661251647132), size=4), Delivery(id='5a1d00fc8dc1ee2a901740b55cdd36aa', point=Point(lng=-47.76340110906013, lat=-15.668974870973102), size=1), Delivery(id='eebf0d97e6829796d7c012d3d0765647', point=Point(lng=-47.75482460546861, lat=-15.65435446002705), size=1), Delivery(id='57da9ab094b982083ebb34aff279de12', point=Point(lng=-47.64215279414541, lat=-15.878651851861552), size=8), Delivery(id='f845770a0d7b472890e79690656a763', point=Point(lng=-47.57874209958461, lat=-15.991660310127441), size=4), Delivery(id='15d98c71ad94232a1115761a84da7c9', point=Point(lng=-47.55621211610284, lat=-15.966403613565724), size=10), Delivery(id='aed58cf97fd337dba1c89831762f00d3', point=Point(lng=-47.60854239379657, lat=-15.891214135632072), size=2), Delivery(id='4e782b0e17bd40c9a0f318d966f72e99', point=Point(lng=-47.487542336969646, lat=-15.858580488239232), size=9), Delivery(id='3d8f2c7c6ba4c6462bcf7c85621fb41c', point=Point(lng=-47.551358952435706, lat=-15.960658771306274), size=4), Delivery(id='8485d5a5d923b3c89984e8bffa643629', point=Point(lng=-47.36431147883306, lat=-16.008278625863653), size=5), Delivery(id='3d5e452ff0745e2b64a77fdc76ac6bc0', point=Point(lng=-47.782004733127586, lat=-15.769477262482981), size=6), Delivery(id='6783bd0655c8fbc6e777ebebe0f15527', point=Point(lng=-47.77758707907217, lat=-15.781651672628128), size=8), Delivery(id='e10ea6109e78b35c16c499616eaf911f', point=Point(lng=-47.79245713258436, lat=-15.786974662992273), size=8), Delivery(id='c5e3917f434fa38cfb0254b3916597f7', point=Point(lng=-47.78983759858604, lat=-15.774223521865341), size=10), Delivery(id='511e2b4c0815bf26c50b14d5e84c8109', point=Point(lng=-47.77551463069359, lat=-15.768527034385663), size=6), Delivery(id='acbb0aca480b56933a43dfdbab0cfc8', point=Point(lng=-47.779011650967796, lat=-15.774153585870373), size=4), Delivery(id='c38c06cb25528a20a460fb4b6c21a6c7', point=Point(lng=-47.77686578547025, lat=-15.765576247632481), size=8), Delivery(id='9f60306edb223f69b9862564ab71be96', point=Point(lng=-47.777872717547446, lat=-15.774946844433602), size=5), Delivery(id='ba478bbd9fbbf79634acad4d8f4838d4', point=Point(lng=-47.79619401454278, lat=-15.784174692103408), size=9), Delivery(id='f8daa49f9d894e0f70bfc93f2adb5a42', point=Point(lng=-47.78251370809103, lat=-15.770385925126604), size=7), Delivery(id='10969a7a6f49c3a4b66a1c85aa7782c5', point=Point(lng=-47.781681465664285, lat=-15.76889693745927), size=8), Delivery(id='dce9f385d725f1fd2b4c4a7ebd8b4d86', point=Point(lng=-47.78246153866734, lat=-15.773817138951719), size=8), Delivery(id='d9853bde69186949fce9bd561731fe99', point=Point(lng=-47.78003963501048, lat=-15.780552324392717), size=3), Delivery(id='69a2bad80b95b4e7ce3841564363504f', point=Point(lng=-47.78153005813718, lat=-15.768129847821786), size=1), Delivery(id='1d6e3635dd095e686d3c73c2484cc2f1', point=Point(lng=-47.775279541036326, lat=-15.772364731420614), size=8), Delivery(id='92704f7920a1734d4f999d31f32 ...

# %%
# Veja estas entregas no mapa
from loggibud.v1.plotting.plot_instance import plot_cvrp_instance


plot_cvrp_instance(problem)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_045c200eba1440d38241e67f8f87f036%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_045c200eba1440d38241e67f8f87f036%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_045c200eba1440d38241e67f8f87f036%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_045c200eba1440d38241e67f8f87f036%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-15.657013854445248%2C%20-47.802664728268745%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Aqui está o código completo do nosso algoritmo trivial desenvolvido na aula:

# %%
from loggibud.v1.types import CVRPSolution, CVRPSolutionVehicle


def solve_vrp_naive_algorithm(problem):
    vehicles = []  # lista com todos os veículos
    vehicle_deliveries = []  # inicializa o primeiro veículo vazio
    for delivery in problem.deliveries:
        if (
            _compute_vehicle_volume(vehicle_deliveries) + delivery.size
            <= problem.vehicle_capacity
        ):
            vehicle_deliveries.append(delivery)
        else:
            vehicle_solution = _construct_vehicle(problem, vehicle_deliveries)
            vehicles.append(vehicle_solution)
            # Inicializa novo veículo com o pacote atual
            vehicle_deliveries = [delivery]

    # Complete a rota do veículo final que sobrou
    if vehicle_deliveries:
        vehicle_solution = _construct_vehicle(problem, vehicle_deliveries)
        vehicles.append(vehicle_solution)

    # Ao final, retorne uma variável do tipo `CVRPSolution`
    return CVRPSolution(name=problem.name, vehicles=vehicles)


def _compute_vehicle_volume(deliveries):
    volume = 0
    for delivery in deliveries:
        volume += delivery.size
    return volume


def _construct_vehicle(problem, vehicle_deliveries):
    return CVRPSolutionVehicle(
        origin=problem.origin, deliveries=vehicle_deliveries
    )

# %%
# Resolvendo para a instância pedida
solution = solve_vrp_naive_algorithm(problem)
solution
# Out:
# CVRPSolution(name='cvrp-0-df-0', vehicles=[CVRPSolutionVehicle(origin=Point(lng=-47.802664728268745, lat=-15.657013854445248), deliveries=[Delivery(id='ed0993f8cc70d998342f38ee827176dc', point=Point(lng=-47.7496622016347, lat=-15.65879313293694), size=10), Delivery(id='c7220154adc7a3def8f0b2b8a42677a9', point=Point(lng=-47.75887552060412, lat=-15.651440380492554), size=10), Delivery(id='54e598b20ffa2707d01b1ac00942793f', point=Point(lng=-47.755018806591394, lat=-15.651207309372888), size=7), Delivery(id='64812681ba8c280649f764b9fb40936a', point=Point(lng=-47.758785390289965, lat=-15.648706444367969), size=3), Delivery(id='c17ea5bb3bdb1346ea358516cba81e5c', point=Point(lng=-47.75284167302011, lat=-15.66047286919706), size=10), Delivery(id='fb1b2bc2ac3783706de766e715cb9d01', point=Point(lng=-47.74788198106806, lat=-15.663388754816273), size=3), Delivery(id='c667f779151bd4e23e91d3b4659ffd94', point=Point(lng=-47.75836162961292, lat=-15.648355505737312), size=5), Delivery(id='7b315f77e3dfded7448866984942da14', point=Point(lng=-47.71947511765923, lat=-15.696661251647132), size=4), Delivery(id='5a1d00fc8dc1ee2a901740b55cdd36aa', point=Point(lng=-47.76340110906013, lat=-15.668974870973102), size=1), Delivery(id='eebf0d97e6829796d7c012d3d0765647', point=Point(lng=-47.75482460546861, lat=-15.65435446002705), size=1), Delivery(id='57da9ab094b982083ebb34aff279de12', point=Point(lng=-47.64215279414541, lat=-15.878651851861552), size=8), Delivery(id='f845770a0d7b472890e79690656a763', point=Point(lng=-47.57874209958461, lat=-15.991660310127441), size=4), Delivery(id='15d98c71ad94232a1115761a84da7c9', point=Point(lng=-47.55621211610284, lat=-15.966403613565724), size=10), Delivery(id='aed58cf97fd337dba1c89831762f00d3', point=Point(lng=-47.60854239379657, lat=-15.891214135632072), size=2), Delivery(id='4e782b0e17bd40c9a0f318d966f72e99', point=Point(lng=-47.487542336969646, lat=-15.858580488239232), size=9), Delivery(id='3d8f2c7c6ba4c6462bcf7c85621fb41c', point=Point(lng=-47.551358952435706, lat=-15.960658771306274), size=4), Delivery(id='8485d5a5d923b3c89984e8bffa643629', point=Point(lng=-47.36431147883306, lat=-16.008278625863653), size=5), Delivery(id='3d5e452ff0745e2b64a77fdc76ac6bc0', point=Point(lng=-47.782004733127586, lat=-15.769477262482981), size=6), Delivery(id='6783bd0655c8fbc6e777ebebe0f15527', point=Point(lng=-47.77758707907217, lat=-15.781651672628128), size=8), Delivery(id='e10ea6109e78b35c16c499616eaf911f', point=Point(lng=-47.79245713258436, lat=-15.786974662992273), size=8), Delivery(id='c5e3917f434fa38cfb0254b3916597f7', point=Point(lng=-47.78983759858604, lat=-15.774223521865341), size=10), Delivery(id='511e2b4c0815bf26c50b14d5e84c8109', point=Point(lng=-47.77551463069359, lat=-15.768527034385663), size=6), Delivery(id='acbb0aca480b56933a43dfdbab0cfc8', point=Point(lng=-47.779011650967796, lat=-15.774153585870373), size=4), Delivery(id='c38c06cb25528a20a460fb4b6c21a6c7', point=Point(lng=-47.77686578547025, lat=-15.765576247632481), size=8), Delivery(id='9f60306edb223f69b9862564ab71be96', point=Point(lng=-47.777872717547446, lat=-15.774946844433602), size=5), Delivery(id='ba478bbd9fbbf79634acad4d8f4838d4', point=Point(lng=-47.79619401454278, lat=-15.784174692103408), size=9), Delivery(id='f8daa49f9d894e0f70bfc93f2adb5a42', point=Point(lng=-47.78251370809103, lat=-15.770385925126604), size=7), Delivery(id='10969a7a6f49c3a4b66a1c85aa7782c5', point=Point(lng=-47.781681465664285, lat=-15.76889693745927), size=8)]), CVRPSolutionVehicle(origin=Point(lng=-47.802664728268745, lat=-15.657013854445248), deliveries=[Delivery(id='dce9f385d725f1fd2b4c4a7ebd8b4d86', point=Point(lng=-47.78246153866734, lat=-15.773817138951719), size=8), Delivery(id='d9853bde69186949fce9bd561731fe99', point=Point(lng=-47.78003963501048, lat=-15.780552324392717), size=3), Delivery(id='69a2bad80b95b4e7ce3841564363504f', point=Point(lng=-47.78153005813718, lat=-15.768129847821786), size=1), Delivery(id='1d6e3635dd095e686d3c73c2484cc2f1', point=Point(lng=-47.7 ...

# %%
print(f"A solução contém {len(solution.vehicles)} veículos")
# Out:
# A solução contém 33 veículos

# %%
from loggibud.v1.eval.task1 import evaluate_solution


total_distance = evaluate_solution(problem, solution, config=osrm_config)
print(f"O percurso completo leva {total_distance} km")
# Out:
# O percurso completo leva 4210.638 km

# %% [markdown]
# Vamos visualizar estas rotas

# %%
from loggibud.v1.plotting.plot_solution import plot_cvrp_solution


plot_cvrp_solution(solution)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c6276f0f620147a99011fdd8665711c4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c6276f0f620147a99011fdd8665711c4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c6276f0f620147a99011fdd8665711c4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c6276f0f620147a99011fdd8665711c4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-15.657013854445253%2C%20-47.802664728268766%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Claramente temos aqui uma bagunça. Portanto, vamos focar nossa atenção nas três primeiras rotas apenas:

# %%
plot_cvrp_solution(solution, route_indices_to_plot=[0, 1, 2])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bc85b4ea6d834730acb5de7c06ae8bd8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bc85b4ea6d834730acb5de7c06ae8bd8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bc85b4ea6d834730acb5de7c06ae8bd8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bc85b4ea6d834730acb5de7c06ae8bd8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-15.657013854445253%2C%20-47.802664728268766%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Observe a quantidade de zigue-zagues obtidos em cada rota. Apesar de nossa solução ser simples e rápida, ela claramente seria rejeitada por qualquer empresa séria por causar este tipo de ineficiência.
#
# Experimente depois ver como ficam as rotas em rua.

# %% [markdown]
# # Exercício 2

# %% [markdown]
# Aqui está o código completo do solver trivial com o TSP

# %%
import numpy as np
from ortools.constraint_solver import pywrapcp

from loggibud.v1.distances import calculate_distance_matrix_m, OSRMConfig
from loggibud.v1.types import CVRPSolution, CVRPSolutionVehicle


def solve_vrp_naive_algorithm_with_tsp(problem):
    vehicles = []  # lista com todos os veículos
    vehicle_deliveries = []  # inicializa o primeiro veículo vazio
    for delivery in problem.deliveries:
        if (
            _compute_vehicle_volume(vehicle_deliveries) + delivery.size
            <= problem.vehicle_capacity
        ):
            vehicle_deliveries.append(delivery)
        else:
            vehicle_solution = _construct_vehicle(problem, vehicle_deliveries)
            vehicles.append(vehicle_solution)
            # Inicializa novo veículo com o pacote atual
            vehicle_deliveries = [delivery]

    # Complete a rota do veículo final que sobrou
    if vehicle_deliveries:
        vehicle_solution = _construct_vehicle(problem, vehicle_deliveries)
        vehicles.append(vehicle_solution)

    # Ao final, retorne uma variável do tipo `CVRPSolution`
    return CVRPSolution(name=problem.name, vehicles=vehicles)


def _compute_vehicle_volume(deliveries):
    volume = 0
    for delivery in deliveries:
        volume += delivery.size
    return volume


def _construct_vehicle(problem, vehicle_deliveries):
    distance_matrix = _compute_distance_matrix(problem, vehicle_deliveries)
    ordered_indices, _ = solve_tsp_ortools(distance_matrix)

    # `ordered_indices` tem o formato `[0, 4, 3, 1, ..., 0]`. Precisamos
    # remover a origem do início e do final e ordenar a variável
    # `vehicle_deliveries` usando estes índices
    ordered_vehicle_deliveries = []
    for ordered_index in ordered_indices[1:-1]:
        ordered_vehicle_deliveries.append(
            vehicle_deliveries[ordered_index - 1]
        )

    return CVRPSolutionVehicle(
        origin=problem.origin, deliveries=ordered_vehicle_deliveries
    )


def _compute_distance_matrix(problem, vehicle_deliveries):
    # Os pontos do problema consistem na origem mais as entregas em
    # `vehicle_deliveries`
    points = [problem.origin]
    for delivery in vehicle_deliveries:
        points.append(delivery.point)

    # Configuração com o servidor para os alunos
    return calculate_distance_matrix_m(points, config=osrm_config)


def solve_tsp_ortools(distance_matrix):
    n = distance_matrix.shape[0]  # número de nós do problema
    num_vehicles = 1  # número de veículos (no nosso caso, apenas um)
    depot_node = 0  # número do nó que representa o ponto de origem
    manager = pywrapcp.RoutingIndexManager(n, num_vehicles, depot_node)
    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(i, j):
        # `i` e `j` são índices internos do OR-Tools. Precisamos primeiro
        # convertê-los em nós do nosso problema
        ni = manager.IndexToNode(i)
        nj = manager.IndexToNode(j)
        return distance_matrix[ni, nj]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Resolve o problema com métodos default
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    solution = routing.SolveWithParameters(search_parameters)

    # Constroi a rota final
    route = []
    index = routing.Start(0)
    node = manager.IndexToNode(index)
    route.append(node)

    while not routing.IsEnd(index):
        index = solution.Value(routing.NextVar(index))
        node = manager.IndexToNode(index)
        route.append(node)

    return route, solution.ObjectiveValue()

# %% [markdown]
# Resolvendo o mesmo problema de antes, temos (observe que, graças ao TSP, a solução pode levar um pouco mais de tempo):

# %%
from loggibud.v1.types import CVRPInstance

file_path = "./data/cvrp-instances-1.0/train/df-0/cvrp-0-df-0.json"
problem = CVRPInstance.from_file(file_path)
solution = solve_vrp_naive_algorithm_with_tsp(problem)
solution
# Out:
# CVRPSolution(name='cvrp-0-df-0', vehicles=[CVRPSolutionVehicle(origin=Point(lng=-47.802664728268745, lat=-15.657013854445248), deliveries=[Delivery(id='64812681ba8c280649f764b9fb40936a', point=Point(lng=-47.758785390289965, lat=-15.648706444367969), size=3), Delivery(id='c667f779151bd4e23e91d3b4659ffd94', point=Point(lng=-47.75836162961292, lat=-15.648355505737312), size=5), Delivery(id='54e598b20ffa2707d01b1ac00942793f', point=Point(lng=-47.755018806591394, lat=-15.651207309372888), size=7), Delivery(id='c7220154adc7a3def8f0b2b8a42677a9', point=Point(lng=-47.75887552060412, lat=-15.651440380492554), size=10), Delivery(id='eebf0d97e6829796d7c012d3d0765647', point=Point(lng=-47.75482460546861, lat=-15.65435446002705), size=1), Delivery(id='5a1d00fc8dc1ee2a901740b55cdd36aa', point=Point(lng=-47.76340110906013, lat=-15.668974870973102), size=1), Delivery(id='ed0993f8cc70d998342f38ee827176dc', point=Point(lng=-47.7496622016347, lat=-15.65879313293694), size=10), Delivery(id='c17ea5bb3bdb1346ea358516cba81e5c', point=Point(lng=-47.75284167302011, lat=-15.66047286919706), size=10), Delivery(id='fb1b2bc2ac3783706de766e715cb9d01', point=Point(lng=-47.74788198106806, lat=-15.663388754816273), size=3), Delivery(id='7b315f77e3dfded7448866984942da14', point=Point(lng=-47.71947511765923, lat=-15.696661251647132), size=4), Delivery(id='4e782b0e17bd40c9a0f318d966f72e99', point=Point(lng=-47.487542336969646, lat=-15.858580488239232), size=9), Delivery(id='8485d5a5d923b3c89984e8bffa643629', point=Point(lng=-47.36431147883306, lat=-16.008278625863653), size=5), Delivery(id='f845770a0d7b472890e79690656a763', point=Point(lng=-47.57874209958461, lat=-15.991660310127441), size=4), Delivery(id='15d98c71ad94232a1115761a84da7c9', point=Point(lng=-47.55621211610284, lat=-15.966403613565724), size=10), Delivery(id='3d8f2c7c6ba4c6462bcf7c85621fb41c', point=Point(lng=-47.551358952435706, lat=-15.960658771306274), size=4), Delivery(id='aed58cf97fd337dba1c89831762f00d3', point=Point(lng=-47.60854239379657, lat=-15.891214135632072), size=2), Delivery(id='57da9ab094b982083ebb34aff279de12', point=Point(lng=-47.64215279414541, lat=-15.878651851861552), size=8), Delivery(id='10969a7a6f49c3a4b66a1c85aa7782c5', point=Point(lng=-47.781681465664285, lat=-15.76889693745927), size=8), Delivery(id='3d5e452ff0745e2b64a77fdc76ac6bc0', point=Point(lng=-47.782004733127586, lat=-15.769477262482981), size=6), Delivery(id='f8daa49f9d894e0f70bfc93f2adb5a42', point=Point(lng=-47.78251370809103, lat=-15.770385925126604), size=7), Delivery(id='c5e3917f434fa38cfb0254b3916597f7', point=Point(lng=-47.78983759858604, lat=-15.774223521865341), size=10), Delivery(id='ba478bbd9fbbf79634acad4d8f4838d4', point=Point(lng=-47.79619401454278, lat=-15.784174692103408), size=9), Delivery(id='e10ea6109e78b35c16c499616eaf911f', point=Point(lng=-47.79245713258436, lat=-15.786974662992273), size=8), Delivery(id='6783bd0655c8fbc6e777ebebe0f15527', point=Point(lng=-47.77758707907217, lat=-15.781651672628128), size=8), Delivery(id='acbb0aca480b56933a43dfdbab0cfc8', point=Point(lng=-47.779011650967796, lat=-15.774153585870373), size=4), Delivery(id='9f60306edb223f69b9862564ab71be96', point=Point(lng=-47.777872717547446, lat=-15.774946844433602), size=5), Delivery(id='511e2b4c0815bf26c50b14d5e84c8109', point=Point(lng=-47.77551463069359, lat=-15.768527034385663), size=6), Delivery(id='c38c06cb25528a20a460fb4b6c21a6c7', point=Point(lng=-47.77686578547025, lat=-15.765576247632481), size=8)]), CVRPSolutionVehicle(origin=Point(lng=-47.802664728268745, lat=-15.657013854445248), deliveries=[Delivery(id='69a2bad80b95b4e7ce3841564363504f', point=Point(lng=-47.78153005813718, lat=-15.768129847821786), size=1), Delivery(id='204f67871cc6bef025975bb516b552f8', point=Point(lng=-47.78221753681825, lat=-15.769082434687933), size=1), Delivery(id='740a919ce285b17a9dbf1e4f1aa500da', point=Point(lng=-47.78392470736934, lat=-15.769858632085061), size=2), Delivery(id='dce9f385d725f1fd2b4c4a7ebd8b4d86', point=Point(lng=-47.7 ...

# %%
from loggibud.v1.eval.task1 import evaluate_solution


total_distance = evaluate_solution(problem, solution, config=osrm_config)
print(f"O percurso completo leva {total_distance} km")
# Out:
# O percurso completo leva 2292.8135 km

# %% [markdown]
# Observe como a distância total é reduzida para quase a metade ao utilizar o TSP.

# %%
from loggibud.v1.plotting.plot_solution import plot_cvrp_solution


plot_cvrp_solution(solution)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6d0ded151bca4c40a90d4d8e7bbaac42%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6d0ded151bca4c40a90d4d8e7bbaac42%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6d0ded151bca4c40a90d4d8e7bbaac42%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6d0ded151bca4c40a90d4d8e7bbaac42%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-15.657013854445253%2C%20-47.802664728268766%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Observe o poder do TSP ao converter as rotas em algo muito menos bagunçado comparado com antes.
#
# Experimente comparar os dois solvers em outras instâncias para ver as melhoras obtidas.

# %% [markdown]
# # Exercício 3

# %%
import numpy as np

from loggibud.v1.distances import calculate_distance_matrix_m, OSRMConfig
from loggibud.v1.types import CVRPSolution, CVRPSolutionVehicle


def solve_vrp_constructive_algorithm_with_tsp(problem):
    vehicles = []  # lista com todos os veículos
    for delivery in problem.deliveries:
        available_vehicles = _filter_available_vehicles(
            problem, vehicles, delivery
        )
        vehicle_number = _compute_delivery_distance_from_vehicles(
            problem, available_vehicles, delivery
        )

        # Se `vehicle_number` == -1, criamos um novo veículo com esta entrega
        if vehicle_number < 0:
            vehicles.append([delivery])
        # Senão, adicione a entrega no `vehicle_number`
        else:
            available_vehicles[vehicle_number].append(delivery)

    # Ao final construa rotas com cada veículo
    vehicle_solutions = []
    for vehicle_deliveries in vehicles:
        vehicle_solution = _construct_vehicle(problem, vehicle_deliveries)
        vehicle_solutions.append(vehicle_solution)

    return CVRPSolution(name=problem.name, vehicles=vehicle_solutions)


def _filter_available_vehicles(problem, vehicles, delivery):
    """
    Filtra os veículos com volume restante suficiente para caber um novo pacote
    """
    available_vehicles = []
    for vehicle_deliveries in vehicles:
        if (
            _compute_vehicle_volume(vehicle_deliveries) + delivery.size
            <= problem.vehicle_capacity
        ):
            available_vehicles.append(vehicle_deliveries)

    return available_vehicles


def _compute_vehicle_volume(deliveries):
    volume = 0
    for delivery in deliveries:
        volume += delivery.size
    return volume


def _compute_delivery_distance_from_vehicles(
    problem, available_vehicles, delivery
):
    """
    Calcula a distância de `delivery` à origem e a cada pacote dos veículos
    disponíveis e retorna o veículo mais próximo.
    """

    # Inicializa `points` com a entrega atual e a origem
    # Inicializa também `vehicle_numbers` com -1 já que estes pontos não
    # percentem a nenhum veículos
    points = [delivery.point, problem.origin]
    vehicle_numbers = [-1, -1]

    # Extrai os pontos de cada veículos
    for i, vehicle_deliveries in enumerate(available_vehicles):
        for delivery in vehicle_deliveries:
            points.append(delivery.point)
            vehicle_numbers.append(i)

    # Calcula a matriz de distâncias
    distance_matrix = calculate_distance_matrix_m(points, config=osrm_config)

    # Determina o ponto mais próximo da entrega atual
    distance_matrix[0, 0] = np.inf
    imin = distance_matrix[0].argmin()
    return vehicle_numbers[imin]


def _construct_vehicle(problem, vehicle_deliveries):
    distance_matrix = _compute_distance_matrix(problem, vehicle_deliveries)
    ordered_indices, _ = solve_tsp_ortools(distance_matrix)

    # `ordered_indices` tem o formato `[0, 4, 3, 1, ..., 0]`. Precisamos
    # remover a origem do início e do final e ordenar a variável
    # `vehicle_deliveries` usando estes índices
    ordered_vehicle = []
    for ordered_index in ordered_indices[1:-1]:
        ordered_vehicle.append(vehicle_deliveries[ordered_index - 1])

    return CVRPSolutionVehicle(
        origin=problem.origin, deliveries=ordered_vehicle
    )


def _compute_distance_matrix(problem, vehicle_deliveries):
    # Os pontos do problema consistem na origem mais as entregas em
    # `vehicle_deliveries`
    points = [problem.origin]
    for delivery in vehicle_deliveries:
        points.append(delivery.point)

    # Configuração com o servidor para os alunos
    return calculate_distance_matrix_m(points, config=osrm_config)

# %%
from loggibud.v1.types import CVRPInstance

file_path = "./data/cvrp-instances-1.0/train/df-0/cvrp-0-df-0.json"
problem = CVRPInstance.from_file(file_path)
solution = solve_vrp_constructive_algorithm_with_tsp(problem)
solution
# Out:
# CVRPSolution(name='cvrp-0-df-0', vehicles=[CVRPSolutionVehicle(origin=Point(lng=-47.802664728268745, lat=-15.657013854445248), deliveries=[Delivery(id='64812681ba8c280649f764b9fb40936a', point=Point(lng=-47.758785390289965, lat=-15.648706444367969), size=3), Delivery(id='c667f779151bd4e23e91d3b4659ffd94', point=Point(lng=-47.75836162961292, lat=-15.648355505737312), size=5), Delivery(id='54e598b20ffa2707d01b1ac00942793f', point=Point(lng=-47.755018806591394, lat=-15.651207309372888), size=7), Delivery(id='c7220154adc7a3def8f0b2b8a42677a9', point=Point(lng=-47.75887552060412, lat=-15.651440380492554), size=10), Delivery(id='eebf0d97e6829796d7c012d3d0765647', point=Point(lng=-47.75482460546861, lat=-15.65435446002705), size=1), Delivery(id='5a1d00fc8dc1ee2a901740b55cdd36aa', point=Point(lng=-47.76340110906013, lat=-15.668974870973102), size=1), Delivery(id='c17ea5bb3bdb1346ea358516cba81e5c', point=Point(lng=-47.75284167302011, lat=-15.66047286919706), size=10), Delivery(id='ed0993f8cc70d998342f38ee827176dc', point=Point(lng=-47.7496622016347, lat=-15.65879313293694), size=10), Delivery(id='fb1b2bc2ac3783706de766e715cb9d01', point=Point(lng=-47.74788198106806, lat=-15.663388754816273), size=3), Delivery(id='7b315f77e3dfded7448866984942da14', point=Point(lng=-47.71947511765923, lat=-15.696661251647132), size=4), Delivery(id='4e782b0e17bd40c9a0f318d966f72e99', point=Point(lng=-47.487542336969646, lat=-15.858580488239232), size=9), Delivery(id='8485d5a5d923b3c89984e8bffa643629', point=Point(lng=-47.36431147883306, lat=-16.008278625863653), size=5), Delivery(id='f845770a0d7b472890e79690656a763', point=Point(lng=-47.57874209958461, lat=-15.991660310127441), size=4), Delivery(id='15d98c71ad94232a1115761a84da7c9', point=Point(lng=-47.55621211610284, lat=-15.966403613565724), size=10), Delivery(id='3d8f2c7c6ba4c6462bcf7c85621fb41c', point=Point(lng=-47.551358952435706, lat=-15.960658771306274), size=4), Delivery(id='aed58cf97fd337dba1c89831762f00d3', point=Point(lng=-47.60854239379657, lat=-15.891214135632072), size=2), Delivery(id='57da9ab094b982083ebb34aff279de12', point=Point(lng=-47.64215279414541, lat=-15.878651851861552), size=8), Delivery(id='69a2bad80b95b4e7ce3841564363504f', point=Point(lng=-47.78153005813718, lat=-15.768129847821786), size=1), Delivery(id='10969a7a6f49c3a4b66a1c85aa7782c5', point=Point(lng=-47.781681465664285, lat=-15.76889693745927), size=8), Delivery(id='3d5e452ff0745e2b64a77fdc76ac6bc0', point=Point(lng=-47.782004733127586, lat=-15.769477262482981), size=6), Delivery(id='f8daa49f9d894e0f70bfc93f2adb5a42', point=Point(lng=-47.78251370809103, lat=-15.770385925126604), size=7), Delivery(id='c5e3917f434fa38cfb0254b3916597f7', point=Point(lng=-47.78983759858604, lat=-15.774223521865341), size=10), Delivery(id='ba478bbd9fbbf79634acad4d8f4838d4', point=Point(lng=-47.79619401454278, lat=-15.784174692103408), size=9), Delivery(id='e10ea6109e78b35c16c499616eaf911f', point=Point(lng=-47.79245713258436, lat=-15.786974662992273), size=8), Delivery(id='d9853bde69186949fce9bd561731fe99', point=Point(lng=-47.78003963501048, lat=-15.780552324392717), size=3), Delivery(id='6783bd0655c8fbc6e777ebebe0f15527', point=Point(lng=-47.77758707907217, lat=-15.781651672628128), size=8), Delivery(id='acbb0aca480b56933a43dfdbab0cfc8', point=Point(lng=-47.779011650967796, lat=-15.774153585870373), size=4), Delivery(id='9f60306edb223f69b9862564ab71be96', point=Point(lng=-47.777872717547446, lat=-15.774946844433602), size=5), Delivery(id='511e2b4c0815bf26c50b14d5e84c8109', point=Point(lng=-47.77551463069359, lat=-15.768527034385663), size=6), Delivery(id='f8075f6dce2bae4cb4e52028d4d4eadd', point=Point(lng=-47.77493624206587, lat=-15.768772042009102), size=1), Delivery(id='c38c06cb25528a20a460fb4b6c21a6c7', point=Point(lng=-47.77686578547025, lat=-15.765576247632481), size=8)]), CVRPSolutionVehicle(origin=Point(lng=-47.802664728268745, lat=-15.657013854445248), deliveries=[Delivery(id='6f2bb72186b95ac4b7eca54b001dc0e4', point=Point(lng=-47.7 ...

# %%
from loggibud.v1.eval.task1 import evaluate_solution


total_distance = evaluate_solution(problem, solution, config=osrm_config)
print(f"O percurso completo leva {total_distance} km")
# Out:
# O percurso completo leva 2222.0534 km

# %%
from loggibud.v1.plotting.plot_solution import plot_cvrp_solution


plot_cvrp_solution(solution)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_87ab4928ee5b422eb7a50ba9d433f839%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_87ab4928ee5b422eb7a50ba9d433f839%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_87ab4928ee5b422eb7a50ba9d433f839%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_87ab4928ee5b422eb7a50ba9d433f839%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-15.657013854445253%2C%20-47.80266472826877%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# Este solver é claramente mais demorado, o que é esperado dada a quantidade de operações feitas para cada pacote. A melhoria na solução parece também não compensar este aumento no processamento.
#
# Será que isto é suficiente para dizer que ele não vale a pena?
#
# Resolva os exercícios suplementares e experimente ver o quão robusto ele é quando a ordem dos pacotes é alterada.
